# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/Users/jordanwegner/Downloads/lgbm_20230808_cv_results.csv')

# %%
df.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      15.096216      1.560161         0.015044        0.003215
# 1      13.387997      1.872875         0.015182        0.008365
# 2      10.298913      0.597445         0.007392        0.000741
# 3      10.552987      0.620790         0.014708        0.009363
# 4      24.023182      6.767745         0.037602        0.025134
#
#    param_subsample_for_bin  param_subsample  param_num_leaves  \
# 0                    10000              0.3                15
# 1                    10000              0.6                45
# 2                     5000              0.6                15
# 3                    20000              0.6                30
# 4                    10000              0.6                45
#
#    param_n_estimators  param_min_child_weight  param_min_child_samples  ...  \
# 0                2000                      12                       10  ...
# ...

# %%
df.sort_values('rank_test_score',inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /Users/jordanwegner/opt/anaconda3/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df.columns
# Out:
# Index(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time',
#        'param_subsample_for_bin', 'param_subsample', 'param_num_leaves',
#        'param_n_estimators', 'param_min_child_weight',
#        'param_min_child_samples', 'param_max_depth', 'param_learning_rate',
#        'param_lambda_l2', 'param_lambda_l1', 'param_colsample_bytree',
#        'param_boosting_type', 'params', 'split0_test_score',
#        'split1_test_score', 'split2_test_score', 'mean_test_score',
#        'std_test_score', 'rank_test_score', 'split0_train_score',
#        'split1_train_score', 'split2_train_score', 'mean_train_score',
#        'std_train_score'],
#       dtype='object')

# %%
cv = df[['param_subsample_for_bin', 'param_subsample', 'param_num_leaves',
       'param_n_estimators', 'param_min_child_weight',
       'param_min_child_samples', 'param_max_depth', 'param_learning_rate',
       'param_lambda_l2', 'param_lambda_l1', 'param_colsample_bytree',
       'param_boosting_type','mean_test_score','mean_train_score']].copy()

# %% [markdown]
# ## Testing Score

# %%
sns.boxplot(x=cv['param_subsample_for_bin'],y=cv['mean_test_score'])
plt.show() # keep the same

# %%
sns.boxplot(x=cv['param_subsample'],y=cv['mean_test_score'])
plt.show() # .3, .4, .5

# %%
sns.boxplot(x=cv['param_num_leaves'],y=cv['mean_test_score'])
plt.show() # 25, 30, 35

# %%
sns.boxplot(x=cv['param_n_estimators'],y=cv['mean_test_score'])
plt.show() # 800, 1200, 1600

# %%
sns.boxplot(x=cv['param_min_child_weight'],y=cv['mean_test_score'])
plt.show() # 13, 14, 15

# %%
sns.boxplot(x=cv['param_min_child_samples'],y=cv['mean_test_score'])
plt.show() # 14, 15, 16

# %%
sns.boxplot(x=cv['param_max_depth'],y=cv['mean_test_score'])
plt.show() # 1, 2, 3, 4 
# try 4, 5, 6 later

# %%
sns.boxplot(x=cv['param_learning_rate'],y=cv['mean_test_score'])
plt.show() # .02

# %%
sns.boxplot(x=cv['param_lambda_l2'],y=cv['mean_test_score'])
plt.show() # 10, 11, 12

# %%
sns.boxplot(x=cv['param_lambda_l1'],y=cv['mean_test_score'])
plt.show() # 5, 6, 7

# %%
sns.boxplot(x=cv['param_colsample_bytree'],y=cv['mean_test_score'])
plt.show() .8, .9, 1

# %% [markdown]
# ## Training Score

# %%
sns.boxplot(x=cv['param_subsample_for_bin'],y=cv['mean_train_score'])
plt.show()

# %%
sns.boxplot(x=cv['param_subsample'],y=cv['mean_train_score'])
plt.show()

# %%
sns.boxplot(x=cv['param_num_leaves'],y=cv['mean_train_score'])
plt.show()

# %%
sns.boxplot(x=cv['param_n_estimators'],y=cv['mean_train_score'])
plt.show()

# %%
sns.boxplot(x=cv['param_min_child_weight'],y=cv['mean_train_score'])
plt.show()

# %%
sns.boxplot(x=cv['param_min_child_samples'],y=cv['mean_train_score'])
plt.show()

# %%
sns.boxplot(x=cv['param_max_depth'],y=cv['mean_train_score'])
plt.show()

# %%
sns.boxplot(x=cv['param_learning_rate'],y=cv['mean_train_score'])
plt.show()

# %%
sns.boxplot(x=cv['param_lambda_l2'],y=cv['mean_train_score'])
plt.show()

# %%
sns.boxplot(x=cv['param_lambda_l1'],y=cv['mean_train_score'])
plt.show()

# %%
sns.boxplot(x=cv['param_colsample_bytree'],y=cv['mean_train_score'])
plt.show()
